# %% [markdown]
# # **Download Dataset from Roboflow**

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QXhc9bzVTCrzqMwt3NnM")
project = rf.workspace("brain-tumor-detection-wsera").project("tumor-detection-ko5jp")
version = project.version(8)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 93.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Tumor-Detection-8 in yolov11:: 100%|██████████| 3924/3924 [00:00<00:00, 7245.93it/s]

# %% [markdown]
# # **Install Library**

# %%
# !pip install ultralytics

# %% [markdown]
# # **Load and Train the YOLOv11 Model**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data="/content/Tumor-Detection-8/data.yaml",  # path to dataset YAML
    epochs=20,  # number of training epochs
    imgsz=640,  # training image size
    device=0,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# Ultralytics 8.3.158 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # **Inference**

# %%
from IPython.display import Image

# %%
Image("/content/runs/detect/train/results.png", width=600)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Perform object detection on an image
results = model("/content/glioma_271_jpg.rf.6bc0439160ce05a380aa64a2dbac9a3c.jpg", save=True)
results[0].show()
# Out:
# image 1/1 /content/glioma_271_jpg.rf.6bc0439160ce05a380aa64a2dbac9a3c.jpg: 640x640 2 gliomas, 16.2ms
# Speed: 2.6ms preprocess, 16.2ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict9
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
# Load a model
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Perform object detection on an image
results = model("/content/Tumor-Detection-8/test/images", save=True)
# Out:
# image 1/191 /content/Tumor-Detection-8/test/images/glioma_1025_jpg.rf.16f677de0fc84afa6b702f2fb8bdb3c2.jpg: 640x640 3 gliomas, 35.1ms
# image 2/191 /content/Tumor-Detection-8/test/images/glioma_1128_jpg.rf.e50d9e41b37fb138368e116b69077ff7.jpg: 640x640 1 pituitary, 25.7ms
# image 3/191 /content/Tumor-Detection-8/test/images/glioma_1166_jpg.rf.493c4f22cb16b11580eabec42f51c3de.jpg: 640x640 1 meningioma, 17.4ms
# image 4/191 /content/Tumor-Detection-8/test/images/glioma_1246_jpg.rf.af4ca1f2e92bf1e7df0360136f128877.jpg: 640x640 1 glioma, 18.8ms
# image 5/191 /content/Tumor-Detection-8/test/images/glioma_20_jpg.rf.8fdf825f9ca269bc07429aee7781e8d9.jpg: 640x640 1 glioma, 19.5ms
# image 6/191 /content/Tumor-Detection-8/test/images/glioma_271_jpg.rf.6bc0439160ce05a380aa64a2dbac9a3c.jpg: 640x640 2 gliomas, 40.3ms
# image 7/191 /content/Tumor-Detection-8/test/images/glioma_303_jpg.rf.6410c94058edf9c93866ef5805b93160.jpg: 640x640 3 gliomas, 16.6ms
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train/weights/best.pt")  # pretrained YOLO11n model

# Run batched inference on a list of images
results = model("/content/Tumor-Detection-8/test/images/glioma_1025_jpg.rf.16f677de0fc84afa6b702f2fb8bdb3c2.jpg")  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    print(boxes)
# Out:
# image 1/1 /content/Tumor-Detection-8/test/images/glioma_1025_jpg.rf.16f677de0fc84afa6b702f2fb8bdb3c2.jpg: 640x640 3 gliomas, 35.3ms
# Speed: 2.7ms preprocess, 35.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1., 1., 1.], device='cuda:0')
# conf: tensor([0.5529, 0.4134, 0.2748], device='cuda:0')
# data: tensor([[3.0616e+02, 2.4211e+02, 4.2953e+02, 3.3782e+02, 5.5295e-01, 1.0000e+00],
#         [3.0494e+02, 2.3712e+02, 4.2729e+02, 3.1036e+02, 4.1345e-01, 1.0000e+00],
#         [3.0498e+02, 2.6963e+02, 3.6625e+02, 3.0835e+02, 2.7479e-01, 1.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (640, 640)
# shape: torch.Size([3, 6])
# xywh: tensor([[367.8434, 289.9659, 123.3744,  95.7133],
#         [366.1108, 273.7390, 122.3499,  73.2472],
#         [335.6119, 288.9933,  61.2714,  38.7198]], device='cuda:0')
# xywhn: tensor([[0.5748, 0.4531, 0.1928, 0.1496],
# ...

# %%
from ultralytics import YOLO
from ultralytics import SAM

# Load the YOLO model
yolo_model = YOLO("/content/runs/detect/train/weights/best.pt")  # pretrained YOLO model

# Run batched inference on a list of images
results = yolo_model("/content/Tumor-Detection-8/test/images/meningioma_1038_jpg.rf.1bbe682f1f254698336b40c2fcfb98f6.jpg")  # return a list of Results objects

# Load the SAM model
sam_model = SAM("sam2_b.pt")

for result in results:
     class_ids = result.boxes.cls.int().tolist()  # noqa
     if len(class_ids):
         boxes = result.boxes.xyxy  # Boxes object for bbox outputs
         sam_results = sam_model(result.orig_img, bboxes=boxes, verbose=False, save=True, device=0)
# Out:
# image 1/1 /content/Tumor-Detection-8/test/images/meningioma_1038_jpg.rf.1bbe682f1f254698336b40c2fcfb98f6.jpg: 640x640 1 meningioma, 11.9ms
# Speed: 2.3ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ...
# 100%|██████████| 154M/154M [00:03<00:00, 41.9MB/s]
# Results saved to runs/segment/predict
